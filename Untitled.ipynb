# %%
import pandas as pd
data = pd.DataFrame(pd.read_excel("User_details.xlsx"))

# %%
data
# Out:
#      Unnamed: 0   id Company_Name Firstname Lastname       Phone        Email  \
# 0             0    0       nzftmc       rvx      znj  4961250378  oqz@abc.com
# 1             1    1       kfiuyr       irx      daw  7924835160  pua@abc.com
# 2             2    2       odapbl       rep      fsg  9728356041  vts@abc.com
# 3             3    3       cgyqav       dsa      sjb  2935704861  nhm@abc.com
# 4             4    4       pflxmj       ovl      sxe  2178460359  scl@abc.com
# ..          ...  ...          ...       ...      ...         ...          ...
# 495         495  495       pjynwv       tdc      dvm  2401735986  emw@abc.com
# 496         496  496       njloac       axb      euk  2564083719  teo@abc.com
# 497         497  497       btwofm       dxs      qiy  8374106592  zlc@abc.com
# 498         498  498       vhwdti       xcu      czn  8261735094  jiv@abc.com
# 499         499  499       sdxhan       gfo      kjx  1745896032  jsl@abc.com
#
# ...

# %%
for index,rows in data.iterrows():
    print(rows)
# Out:
# Unnamed: 0                0
# id                        0
# Company_Name         nzftmc
# Firstname               rvx
# Lastname                znj
# Phone            4961250378
# Email           oqz@abc.com
# Address             welqacd
# City                    azc
# District                fjz
# State                  uhze
# Pincode              625974
# GSTIN             245369710
# Pwd                 fobk!*$
# Name: 0, dtype: object
# Unnamed: 0                1
# id                        1
# Company_Name         kfiuyr
# Firstname               irx
# Lastname                daw
# Phone            7924835160
# Email           pua@abc.com
# Address             xvtercy
# City                    dtp
# District                knl
# State                  ugoq
# Pincode              845623
# GSTIN             109675243
# Pwd                 hmou!@-
# Name: 1, dtype: object
# Unnamed: 0                2
# id                        2
# Company_Name         odapbl
# ...

# %%
data.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>id</th>\n      <th>Company_Name</th>\n      <th>Firstname</th>\n      <th>Lastname</th>\n      <th>Phone</th>\n      <th>Email</th>\n      <th>Address</th>\n      <th>City</th>\n      <th>District</th>\n      <th>State</th>\n      <th>Pincode</th>\n      <th>GSTIN</th>\n      <th>Pwd</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>0</td>\n      <td>nzftmc</td>\n      <td>rvx</td>\n      <td>znj</td>\n      <td>4961250378</td>\n      <td>oqz@abc.com</td>\n      <td>welqacd</td>\n      <td>azc</td>\n      <td>fjz</td>\n      <td>uhze</td>\n      <td>625974</td>\n      <td>245369710</td>\n      <td>fobk!*$</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>1</td>\n      <td>kfiuyr</td>\n      <td>irx</td>\n      <td>daw</td>\n      <td>7924835160</td>\n      <td>pua@abc.com</td>\
# ...
